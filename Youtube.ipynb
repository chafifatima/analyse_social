# %%
import pandas as pd

# %% [markdown]
# ### Lecture de data depuis fichier excel  facebook

# %%
df = pd.read_excel("C:/analyse/twitter/facebook.xlsx")

# %%
df.describe()
# Out:
#              likes    comments      shares         views
# count    54.000000   54.000000   54.000000     54.000000
# mean    150.962963   17.925926    8.962963    296.296296
# std     329.970208   64.792514   21.756771   2177.324216
# min       0.000000    0.000000    0.000000      0.000000
# 25%       3.250000    0.000000    0.000000      0.000000
# 50%      19.500000    0.000000    1.000000      0.000000
# 75%      82.750000    4.000000    4.000000      0.000000
# max    1553.000000  445.000000  102.000000  16000.000000

# %% [markdown]
# ## Le tri des lignes de data basant sur les valeurs des interactions

# %%
df.sort_values(by=["likes", "comments", "shares"], ascending=True)
# Out:
#                                             post_link            date_post  \
# 3   https://web.facebook.com/Sihaticom/posts/15045...  2020-09-21 20:54:00
# 35  https://web.facebook.com/FADAEALKHABAR/posts/2...  2020-09-17 00:07:00
# 36  https://web.facebook.com/Sihaticom/posts/14998...  2020-09-16 15:33:00
# 46  https://web.facebook.com/A.Talidi/posts/283913...  2020-09-24 00:04:00
# 48  https://web.facebook.com/themoroccanmarket/pos...  2020-09-23 22:12:00
# 1   https://web.facebook.com/LesEcoMa/posts/444456...  2020-10-01 10:21:00
# 2   https://web.facebook.com/groups/23766548410631...  2020-09-07 19:56:00
# 10  https://web.facebook.com/Sihaticom/posts/14997...  2020-09-16 14:04:00
# 41  https://web.facebook.com/permalink.php?story_f...  2020-09-25 13:58:00
# 5   https://web.facebook.com/groups/46408224773469...  2020-09-21 21:34:00
# 6   https://web.facebook.com/Ecoactu.ma/posts/3248...  2020-09-14 15:50:00
# ...

# %%
data = df.sort_values(by=["likes", "comments", "shares"], ascending=False)

# %% [markdown]
# ## L'affichage des cinq premiers posts sur facebook qui ont le maximum de valeurs d'interactions

# %%
df_1 = data[:5]
df_1
# Out:
#                                             post_link            date_post  \
# 34  https://web.facebook.com/Hespress/posts/101586...  2020-09-16 09:50:00
# 27  https://web.facebook.com/febrayer/posts/414304...  2020-09-23 21:35:00
# 17  https://web.facebook.com/2m.officiel/posts/101...  2020-09-27 15:50:00
# 16  https://web.facebook.com/2m.officiel/posts/101...  2020-09-15 21:50:00
# 13  https://web.facebook.com/al9anat.ma/posts/1529...  2020-09-24 16:45:00
#
#                                           description     page_name type_post  \
# 34  صيادلة المملكة يرغبون في تلقيح المغاربة ضد الأ...      hespress   article
# 27  محمد اليوبي يحذر من خطر فيروس كورونا ان انضافت...  febrayer.com   article
# 17  كورونا تُصيب أكثر من ألف طفل في المغرب.. وتوصي...         2M.ma   article
# 16  الصيادلة يطالبون وزارة الصحة بالترخيص لهم لإجر...         2M.ma   article
# 13  محمد اليوبي مدير مديرية علم الأوبئة ومحاربة ال...        القناة     image
#
#     likes  comments  shares  views Notation
# ...

# %% [markdown]
# ## L'affichage des page facebook qui ont publié dans la thématique et qui ont reconnu les plus réactions des personnes

# %%
result = df_1.groupby("page_name").mean()

# %%
result
# Out:
#               likes  comments  shares  views
# page_name
# 2M.ma           950        61      18      0
# febrayer.com   1220       116      74      0
# hespress       1553       445      45      0
# القناة          687        39      15      0

# %% [markdown]
# ## Le classement des pages facebook selon la réaction des personnes

# %%
result2 = data.groupby("page_name").mean()
result2
# Out:
#                                                         likes  comments  \
# page_name
# 2M.ma                                              595.750000     31.75
# Amallpress أمل بريس                                 59.000000     21.00
# Amine Mouline                                        1.000000      0.00
# Assabah - الصباح                                    84.000000      4.00
# Bladi.net                                           10.000000      1.00
# Chrif EL Bakkali                                    27.000000      4.00
# Ecoactu                                              2.000000      0.00
# Guercif77                                          114.000000      0.00
# H24Info                                             14.000000     13.00
# Kech24 - كِشـ24                                    192.000000      7.00
# Lahassan Ouhnais                                     8.000000      0.00
# Lahlou Najib Allergologue                            1.000000      0.00
# ...

# %% [markdown]
# ## La chart des pages facebook qui ont publier dans la thématique avec les valeurs des intéractions

# %%
result.plot.bar()
# result2.plot.bar()

# %% [markdown]
# ## la chart des pages facebook avec le nombre des posts publiés dans la thématique

# %%
# df_3 = df.groupby('page_name')['page_name']
df_3 = df['page_name'].value_counts()
result3 = df_3[:5]

# %%
result3= df_3[:5].plot.bar()

# %% [markdown]
# ## la chart PIE décrivant le pourcentage selon la notation dans la data provenant de facebook

# %%
# df[:3]
df_4 = df["Notation "].value_counts()
df_4
# Out:
# Négatif    25
# Neutre     23
# Positif     5
# Name: Notation , dtype: int64

# %%
import matplotlib.pyplot as plt
df_4.columns=['Notation', 'somme']

df_4.plot.pie(y='somme', figsize=(5,5))
# fig, axes = plt.subplots(1, 1)
# df_4.iloc[0].plot.pie(ax=axes[0])
# df_4.iloc[1].plot.pie(ax=axes[1])
